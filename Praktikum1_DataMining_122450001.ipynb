# %% [markdown]
# # Nama: Eksanty F Sugma Islamiaty
# # NIM: 122450001
# # Kelas: RA

# %% [markdown]
# ### **Modul Latihan**

# %%
# mengimport pustaka
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load datasets yang sudah diupload
df=pd.read_csv("diabetes.csv") # membuka file csv

# %%
# Menampilkan 5 baris pertama dari data frame
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            7      159             64              0        0  27.4
# 1            0      180             66             39        0  42.0
# 2            1      146             56              0        0  29.7
# 3            2       71             70             27        0  28.0
# 4            7      103             66             32        0  39.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.294   40        0
# 1                     1.893   25        1
# 2                     0.564   29        0
# 3                     0.586   22        0
# 4                     0.344   31        1

# %%
# menampilkan 5 baris terbawah
df.tail()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 15            0      105             64             41      142  41.5
# 16            2       84              0              0        0   0.0
# 17            8      133             72              0        0  32.9
# 18            5       44             62              0        0  25.0
# 19            2      141             58             34      128  25.4
#
#     DiabetesPedigreeFunction  Age  Outcome
# 15                     0.173   22        0
# 16                     0.304   21        0
# 17                     0.270   39        1
# 18                     0.587   36        0
# 19                     0.699   24        0

# %%
# menampilkan baris "n" secara random
df.sample(5)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3             2       71             70             27        0  28.0
# 18            5       44             62              0        0  25.0
# 2             1      146             56              0        0  29.7
# 1             0      180             66             39        0  42.0
# 13            0      100             88             60      110  46.8
#
#     DiabetesPedigreeFunction  Age  Outcome
# 3                      0.586   22        0
# 18                     0.587   36        0
# 2                      0.564   29        0
# 1                      1.893   25        1
# 13                     0.962   31        0

# %%
# memeriksa jumlah baris dan kolom
df.shape
# Out:
# (20, 9)

# %%
# melihat informasi dasar tentang dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               20 non-null     int64
#  1   Glucose                   20 non-null     int64
#  2   BloodPressure             20 non-null     int64
#  3   SkinThickness             20 non-null     int64
#  4   Insulin                   20 non-null     int64
#  5   BMI                       20 non-null     float64
#  6   DiabetesPedigreeFunction  20 non-null     float64
#  7   Age                       20 non-null     int64
#  8   Outcome                   20 non-null     int64
# dtypes: float64(2), int64(7)
# memory usage: 1.5 KB

# %%
# menampilkan jenis data tiap kolom
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# melihat statistik deskriptif dari data numerik
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count    20.000000   20.000000      20.000000      20.000000   20.000000
# mean      3.550000  119.750000      60.900000      20.250000   73.350000
# std       3.136794   39.803299      23.463073      18.970545  114.471911
# min       0.000000   44.000000       0.000000       0.000000    0.000000
# 25%       1.000000   97.000000      57.500000       0.000000    0.000000
# 50%       2.000000  105.000000      66.000000      18.000000    0.000000
# 75%       7.000000  147.000000      70.500000      35.250000  114.500000
# max       8.000000  187.000000      90.000000      60.000000  342.000000
#
#              BMI  DiabetesPedigreeFunction        Age    Outcome
# count  20.000000                 20.000000  20.000000  20.000000
# mean   28.770000                  0.590400  31.400000   0.250000
# std    12.371746                  0.469685   9.981035   0.444262
# ...

# %%
# menampilkan deskripsi data berupa nilai perhitungan statistik pada atribut tertentu
df['Pregnancies'].describe()
# Out:
# count    20.000000
# mean      3.550000
# std       3.136794
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       7.000000
# max       8.000000
# Name: Pregnancies, dtype: float64

# %%
# menampilkan komposisi semua data
df.value_counts()
# Out:
# Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI   DiabetesPedigreeFunction  Age  Outcome
# 0            100      88             60             110      46.8  0.962                     31   0          1
#              105      64             41             142      41.5  0.173                     22   0          1
# 8            133      72             0              0        32.9  0.270                     39   1          1
# 7            187      68             39             304      37.7  0.254                     41   1          1
#              159      64             0              0        27.4  0.294                     40   0          1
#              150      66             42             342      34.7  0.718                     42   0          1
#              105      0              0              0        0.0   0.305                     24   0          1
# ...

# %%
# menampilkan komposisi data suatu atribut
df['Insulin'].value_counts()
# Out:
# Insulin
# 0      11
# 82      1
# 36      1
# 23      1
# 300     1
# 342     1
# 304     1
# 110     1
# 142     1
# 128     1
# Name: count, dtype: int64

# %%
# identifikasi nilai yang hilang
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# identifikasi duplikat data
df.groupby('BMI')['BMI'].agg("count")
# Out:
# BMI
# 0.0     2
# 19.4    1
# 23.0    1
# 24.2    1
# 24.4    1
# 25.0    1
# 25.4    1
# 27.4    1
# 28.0    1
# 29.7    1
# 32.9    1
# 33.7    1
# 34.7    1
# 37.7    1
# 39.1    1
# 40.5    1
# 41.5    1
# 42.0    1
# 46.8    1
# Name: BMI, dtype: int64

# %%
duplikat = df[df.duplicated(keep=False)]
print("Baris Duplikat:")
print(duplikat)
# Out:
# Baris Duplikat:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# identifikasi outlier
correlation_matrix = df.corr() #menghitung korelasi antar kolom
sns.heatmap(correlation_matrix, annot = True) #menampilkan matriks korelasi sebagai heatmap
print(correlation_matrix) #menampilkan nilai korelasi
plt.show() #menampilkan plot
sns.boxplot(x='BMI', data=df) #menampilkan data sebagai boxplot
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.241438      -0.034254      -0.098839
# Glucose                      0.241438  1.000000       0.299956       0.253455
# BloodPressure               -0.034254  0.299956       1.000000       0.447852
# SkinThickness               -0.098839  0.253455       0.447852       1.000000
# Insulin                      0.322928  0.500616       0.332613       0.615901
# BMI                         -0.118628  0.408949       0.831167       0.618654
# DiabetesPedigreeFunction    -0.463170  0.322062       0.312071       0.171401
# Age                          0.596106  0.550986       0.499109       0.063654
# Outcome                      0.462655  0.536493       0.290329       0.266971
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.322928 -0.118628                 -0.463170
# ...

# %%
# identifikasi data tidak berimbang
df['Outcome'].unique() #menampilkan variabel pada atribut outcome
# Out:
# array([0, 1])

# %%
df['Outcome'].value_counts() #menampilkan komposisi pada atribut outcome
# Out:
# Outcome
# 0    15
# 1     5
# Name: count, dtype: int64

# %% [markdown]
# ### **Latihan Mandiri**

# %%
# mengimport pustaka
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load datasets yang sudah diupload
diabetes=pd.read_csv("diabetes_RS1.csv") # membuka file csv

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes.groupby('DiabetesPedigreeFunction')['DiabetesPedigreeFunction'].agg("count")
# Out:
# DiabetesPedigreeFunction
# 0.078    1
# 0.084    1
# 0.085    2
# 0.088    2
# 0.089    1
#         ..
# 1.893    1
# 2.137    1
# 2.288    1
# 2.329    1
# 2.420    1
# Name: DiabetesPedigreeFunction, Length: 517, dtype: int64

# %%
duplikat = diabetes[diabetes.duplicated(keep=False)]
print("Baris Duplikat:")
print(duplikat)
# Out:
# Baris Duplikat:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# identifikasi outlier
correlation_matrix = diabetes.corr() #menghitung korelasi antar kolom
sns.heatmap(correlation_matrix, annot = True) #menampilkan matriks korelasi sebagai heatmap
print(correlation_matrix) #menampilkan nilai korelasi
plt.show() #menampilkan plot
sns.boxplot(x='Age', data=df) #menampilkan data sebagai boxplot
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
diabetes['Age'].describe()
# Out:
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64
